# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time

# %%
# Import the census data into a pandas DataFrame
census_AIAN_2000_pd = pd.read_csv("census_data/AIAN/2000_AIAN_cleaned .csv")

# Preview the data
census_AIAN_2000_pd.head()
# Out:
#    CountyID                      CountyName  TotalPopulation  \
# 0      2020  Anchorage Municipality, Alaska             8091
# 1      4001          Apache County, Arizona            12081
# 2      4005        Coconino County, Arizona             8367
# 3      4013        Maricopa County, Arizona            20744
# 4      4017          Navajo County, Arizona            13271
#
#    Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 0                837                 939                 363
# 1               3130                1404                 794
# 2               1183                 405                 473
# 3               2536                 947                1460
# 4               3975                1255                 707
#
#    $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 0                 222                 748                 585
# 1                1152                 553                 790
# ...

# %%
census_AIAN_2005_pd = pd.read_csv("census_data/AIAN/2005_AIAN_cleaned .csv")
census_AIAN_2005_pd.head()
# Out:
#    CountyID                      CountyName  TotalPopulation  \
# 0      2020  Anchorage Municipality, Alaska             5170
# 1      4001          Apache County, Arizona            13343
# 2      4005        Coconino County, Arizona             8975
# 3      4013        Maricopa County, Arizona            20043
# 4      4017          Navajo County, Arizona            12953
#
#    Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 0                688                 187                 211
# 1               4506                1625                 670
# 2               1771                 651                 944
# 3               2270                2522                1570
# 4               3664                 936                1001
#
#    $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 0                 196                  91                 307
# 1                 746                1059                 948
# ...

# %%
census_AIAN_2008_pd = pd.read_csv("census_data/AIAN/2008_AIAN_cleaned.csv")

# Preview the data
census_AIAN_2008_pd.head()
# Out:
#    CountyID                      CountyName  TotalPopulation  \
# 0      2020  Anchorage Municipality, Alaska             4764
# 1      4001          Apache County, Arizona            10602
# 2      4005        Coconino County, Arizona             9610
# 3      4013        Maricopa County, Arizona            19568
# 4      4017          Navajo County, Arizona            13498
#
#    Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 0                173                 351                 304
# 1               3243                 886                 718
# 2               1492                 586                 611
# 3               2415                 967                1081
# 4               2248                 851                1159
#
#    $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 0                 183                 155                 634
# 1                 721                 486                 462
# ...

# %%
# Import the census data into a pandas DataFrame
census_AIAN_2010_pd = pd.read_csv("census_data/AIAN/2010_AIAN_cleaned.csv")

# Preview the data
census_AIAN_2010_pd.head()
# Out:
#    CountyID                      CountyName  TotalPopulation  \
# 0      2020  Anchorage Municipality, Alaska             8091
# 1      4001          Apache County, Arizona            12081
# 2      4005        Coconino County, Arizona             8367
# 3      4013        Maricopa County, Arizona            20744
# 4      4017          Navajo County, Arizona            13271
#
#    Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 0                837                 939                 363
# 1               3130                1404                 794
# 2               1183                 405                 473
# 3               2536                 947                1460
# 4               3975                1255                 707
#
#    $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 0                 222                 748                 585
# 1                1152                 553                 790
# ...

# %%
# Import the census data into a pandas DataFrame
census_AIAN_2013_pd = pd.read_csv("census_data/AIAN/2013_AIAN_cleaned .csv")

# Preview the data
census_AIAN_2013_pd.head()
# Out:
#    CountyID                      CountyName  TotalPopulation  \
# 0      2020  Anchorage Municipality, Alaska             6669
# 1      4001          Apache County, Arizona            11382
# 2      4005        Coconino County, Arizona             9899
# 3      4013        Maricopa County, Arizona            20703
# 4      4017          Navajo County, Arizona            11588
#
#    Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 0                540                 187                 693
# 1               3126                1288                 811
# 2               1574                 667                1160
# 3               2842                1246                 852
# 4               2887                 928                 846
#
#    $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 0                 386                 214                 471
# 1                1057                 590                 802
# ...

# %%
# Import the census data into a pandas DataFrame
census_AIAN_2016_pd = pd.read_csv("census_data/AIAN/2106_AIAN_cleaned.csv")

# Preview the data
census_AIAN_2016_pd.head()
# Out:
#    CountyID                      CountyName  TotalPopulation  \
# 0      2020  Anchorage Municipality, Alaska             6899
# 1      4001          Apache County, Arizona            13752
# 2      4005        Coconino County, Arizona             9353
# 3      4013        Maricopa County, Arizona            22961
# 4      4017          Navajo County, Arizona            12074
#
#    Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 0                304                 457                 425
# 1               3922                1380                1083
# 2               1626                 615                 437
# 3               1921                 769                 730
# 4               3403                1005                 996
#
#    $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 0                 436                 530                 301
# 1                 803                 759                 747
# ...

# %%
census_AIAN_total_pd=pd.concat([census_AIAN_2000_pd,census_AIAN_2005_pd,census_AIAN_2008_pd, census_AIAN_2010_pd, census_AIAN_2013_pd, census_AIAN_2016_pd],ignore_index=True,
            )
census_AIAN_total_pd.head()
# Out:
#    CountyID                      CountyName  TotalPopulation  \
# 0      2020  Anchorage Municipality, Alaska             8091
# 1      4001          Apache County, Arizona            12081
# 2      4005        Coconino County, Arizona             8367
# 3      4013        Maricopa County, Arizona            20744
# 4      4017          Navajo County, Arizona            13271
#
#    Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 0                837                 939                 363
# 1               3130                1404                 794
# 2               1183                 405                 473
# 3               2536                 947                1460
# 4               3975                1255                 707
#
#    $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 0                 222                 748                 585
# 1                1152                 553                 790
# ...

# %%
# # Save Data to csv
census_AIAN_total_pd.to_csv("census_data/census_AIAN_total_cleaned_pd.csv")
