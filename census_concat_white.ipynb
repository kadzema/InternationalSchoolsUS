# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time

# %%
# Import the census data into a pandas DataFrame
census_white_2000_pd = pd.read_csv("census_data/White/2000_cleaned_white.csv")

# Preview the data
census_white_2000_pd
# Out:
#       CountyID                    CountyName  TotalPopulation  \
# 0         1001       Autauga County, Alabama            13103
# 1         1003       Baldwin County, Alabama            49458
# 2         1005       Barbour County, Alabama             5815
# 3         1007          Bibb County, Alabama             5978
# 4         1009        Blount County, Alabama            18397
# 5         1011       Bullock County, Alabama             1014
# 6         1013        Butler County, Alabama             5231
# 7         1015       Calhoun County, Alabama            36645
# 8         1017      Chambers County, Alabama             9438
# 9         1019      Cherokee County, Alabama             9153
# 10        1021       Chilton County, Alabama            13522
# 11        1023       Choctaw County, Alabama             3656
# 12        1025        Clarke County, Alabama             6318
# 13        1027          Clay County, Alabama             4848
# ...

# %%
census_white_2000_pd.columns
# Out:
# Index(['CountyID', 'CountyName', 'TotalPopulation', 'Less than $10,000',
#        '$10,000 to $14,999', '$15,000 to $19,999', '$20,000 to $24,999',
#        '$25,000 to $29,999', '$30,000 to $34,999', '$35,000 to $39,999',
#        '$40,000 to $44,999', '$45,000 to $49,999', '$50,000 to $59,999',
#        '$60,000 to $74,999', '$75,000 to $99,999', '$100,000 to $124,999',
#        '$125,000 to $149,999', '$150,000 to $199,999', '$200,000 or more',
#        'Year', 'Race'],
#       dtype='object')

# %%
# Import the census data into a pandas DataFrame
census_white_2005_pd = pd.read_csv("census_data/White/2005_cleaned_white.csv")

# Preview the data
census_white_2005_pd
# Out:
#      CountyID                            CountyName  TotalPopulation  \
# 0        1003               Baldwin County, Alabama            58362
# 1        1015               Calhoun County, Alabama            36737
# 2        1043               Cullman County, Alabama            28633
# 3        1049                DeKalb County, Alabama            24065
# 4        1051                Elmore County, Alabama            20743
# 5        1055                Etowah County, Alabama            35619
# 6        1069               Houston County, Alabama            27295
# 7        1073             Jefferson County, Alabama           158885
# 8        1077            Lauderdale County, Alabama            32215
# 9        1081                   Lee County, Alabama            37850
# 10       1083             Limestone County, Alabama            22244
# 11       1089               Madison County, Alabama            89423
# 12       1095              Marshall County, Alabama            32150
# ...

# %%
# Import the census data into a pandas DataFrame
census_white_2008_pd = pd.read_csv("census_data/White/2008_cleaned_white.csv")

# Preview the data
census_white_2008_pd
# Out:
#       CountyID                            CountyName  TotalPopulation  \
# 0         1003               Baldwin County, Alabama            61274
# 1         1015               Calhoun County, Alabama            36624
# 2         1043               Cullman County, Alabama            29836
# 3         1049                DeKalb County, Alabama            23164
# 4         1051                Elmore County, Alabama            21333
# 5         1055                Etowah County, Alabama            34338
# 6         1069               Houston County, Alabama            27773
# 7         1073             Jefferson County, Alabama           151848
# 8         1077            Lauderdale County, Alabama            33246
# 9         1081                   Lee County, Alabama            42468
# 10        1083             Limestone County, Alabama            22447
# 11        1089               Madison County, Alabama            92460
# ...

# %%
# Import the census data into a pandas DataFrame
census_white_2010_pd = pd.read_csv("census_data/White/2010_cleaned_white.csv")

# Preview the data
census_white_2010_pd
# Out:
#       CountyID                            CountyName  TotalPopulation  \
# 0         1003               Baldwin County, Alabama            60891
# 1         1015               Calhoun County, Alabama            36062
# 2         1043               Cullman County, Alabama            29006
# 3         1049                DeKalb County, Alabama            24337
# 4         1051                Elmore County, Alabama            23676
# 5         1055                Etowah County, Alabama            33698
# 6         1069               Houston County, Alabama            29222
# 7         1073             Jefferson County, Alabama           144986
# 8         1077            Lauderdale County, Alabama            34217
# 9         1081                   Lee County, Alabama            40375
# 10        1083             Limestone County, Alabama            26003
# 11        1089               Madison County, Alabama            92969
# ...

# %%
# Import the census data into a pandas DataFrame
census_white_2013_pd = pd.read_csv("census_data/White/2013_cleaned_white.csv")

# Preview the data
census_white_2013_pd
# Out:
#       CountyID                            CountyName  TotalPopulation  \
# 0         1003               Baldwin County, Alabama            61841
# 1         1015               Calhoun County, Alabama            33605
# 2         1043               Cullman County, Alabama            31228
# 3         1049                DeKalb County, Alabama            21221
# 4         1051                Elmore County, Alabama            22793
# 5         1055                Etowah County, Alabama            32668
# 6         1069               Houston County, Alabama            29211
# 7         1073             Jefferson County, Alabama           141966
# 8         1077            Lauderdale County, Alabama            35117
# 9         1081                   Lee County, Alabama            39368
# 10        1083             Limestone County, Alabama            27532
# 11        1089               Madison County, Alabama            97873
# ...

# %%
# Import the census data into a pandas DataFrame
census_white_2016_pd = pd.read_csv("census_data/White/2016_cleaned_white.csv",encoding='ISO-8859-1')

# Preview the data
census_white_2016_pd.head(440)
# Out:
#      CountyID                            CountyName  TotalPopulation  \
# 0        1003               Baldwin County, Alabama            69413
# 1        1015               Calhoun County, Alabama            33611
# 2        1043               Cullman County, Alabama            29268
# 3        1049                DeKalb County, Alabama            22765
# 4        1051                Elmore County, Alabama            22968
# 5        1055                Etowah County, Alabama            31868
# 6        1069               Houston County, Alabama            28054
# 7        1073             Jefferson County, Alabama           141973
# 8        1077            Lauderdale County, Alabama            33433
# 9        1081                   Lee County, Alabama            42089
# 10       1083             Limestone County, Alabama            27235
# 11       1089               Madison County, Alabama            97973
# 12       1095              Marshall County, Alabama            32999
# ...

# %%
# Concatenate dataframes
census_white_total_pd = pd.concat([census_white_2000_pd,census_white_2005_pd,census_white_2008_pd,census_white_2010_pd,census_white_2013_pd,census_white_2016_pd],ignore_index=True)
census_white_total_pd.head()
# Out:
#    CountyID               CountyName  TotalPopulation  Less than $10,000  \
# 0      1001  Autauga County, Alabama            13103                978
# 1      1003  Baldwin County, Alabama            49458               3822
# 2      1005  Barbour County, Alabama             5815                828
# 3      1007     Bibb County, Alabama             5978                647
# 4      1009   Blount County, Alabama            18397               2241
#
#    $10,000 to $14,999  $15,000 to $19,999  $20,000 to $24,999  \
# 0                 668                 604                 768
# 1                3152                2821                3396
# 2                 524                 371                 416
# 3                 569                 401                 523
# 4                1393                1287                1232
#
#    $25,000 to $29,999  $30,000 to $34,999  $35,000 to $39,999  ...    \
# 0                 704                 852                 908  ...
# ...

# %%
# Save Data to csv
census_white_total_pd.to_csv("census_data/census_white_total_cleaned_pd.csv")
