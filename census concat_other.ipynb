# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time

# %%
# Import the census data into a pandas DataFrame
census_other_2000_pd = pd.read_csv("census_data/Other/DEC_00_SF3_P151F_with_ann.csv")

# Preview the data
census_other_2000_pd.head()
# Out:
#            GEO.id GEO.id2        GEO.display-label    VD01               VD02  \
# 0              Id     Id2                Geography  Total:  Less than $10,000
# 1  0500000US01001   01001  Autauga County, Alabama      31                  7
# 2  0500000US01003   01003  Baldwin County, Alabama     212                 22
# 3  0500000US01005   01005  Barbour County, Alabama      57                 10
# 4  0500000US01007   01007     Bibb County, Alabama      15                  0
#
#                  VD03                VD04                VD05  \
# 0  $10,000 to $14,999  $15,000 to $19,999  $20,000 to $24,999
# 1                   0                   0                   8
# 2                  31                   5                  36
# 3                  10                   2                   0
# 4                   0                   0                   0
#
#                  VD06                VD07                VD08  \
# ...

# %%
census_other_2000_pd["Year"] = "2000"
census_other_2000_pd["Race"] = "Other"
census_other_2000_pd.head()
# Out:
#            GEO.id GEO.id2        GEO.display-label    VD01               VD02  \
# 0              Id     Id2                Geography  Total:  Less than $10,000
# 1  0500000US01001   01001  Autauga County, Alabama      31                  7
# 2  0500000US01003   01003  Baldwin County, Alabama     212                 22
# 3  0500000US01005   01005  Barbour County, Alabama      57                 10
# 4  0500000US01007   01007     Bibb County, Alabama      15                  0
#
#                  VD03                VD04                VD05  \
# 0  $10,000 to $14,999  $15,000 to $19,999  $20,000 to $24,999
# 1                   0                   0                   8
# 2                  31                   5                  36
# 3                  10                   2                   0
# 4                   0                   0                   0
#
#                  VD06                VD07  ...                  VD10  \
# ...

# %%
# Import the census data into a pandas DataFrame
census_other_2005_pd = pd.read_csv("census_data/Other/ACS_05_EST_B19001F_with_ann.csv")

# Preview the data
census_other_2005_pd.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label         HD01_VD01  \
# 0              Id     Id2                 Geography  Estimate; Total:
# 1  0500000US04013   04013  Maricopa County, Arizona            101811
# 2  0500000US04019   04019      Pima County, Arizona             46916
# 3  0500000US04021   04021     Pinal County, Arizona             10177
# 4  0500000US04027   04027      Yuma County, Arizona             11391
#
#                  HD02_VD01                    HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Less than $10,000
# 1                     4900                         6562
# 2                     2963                         4345
# 3                     1438                         1102
# 4                     1886                         2547
#
#                             HD02_VD02                     HD01_VD03  \
# 0  Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999
# ...

# %%
census_other_2005_pd["Year"] = "2005"
census_other_2005_pd["Race"] = "Other"
census_other_2005_pd.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label         HD01_VD01  \
# 0              Id     Id2                 Geography  Estimate; Total:
# 1  0500000US04013   04013  Maricopa County, Arizona            101811
# 2  0500000US04019   04019      Pima County, Arizona             46916
# 3  0500000US04021   04021     Pinal County, Arizona             10177
# 4  0500000US04027   04027      Yuma County, Arizona             11391
#
#                  HD02_VD01                    HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Less than $10,000
# 1                     4900                         6562
# 2                     2963                         4345
# 3                     1438                         1102
# 4                     1886                         2547
#
#                             HD02_VD02                     HD01_VD03  \
# 0  Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999
# ...

# %%
# Import the census data into a pandas DataFrame
census_other_2008_pd = pd.read_csv("census_data/Other/ACS_08_1YR_B19001F_with_ann.csv")

# Preview the data
census_other_2008_pd.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label         HD01_VD01  \
# 0              Id     Id2                 Geography  Estimate; Total:
# 1  0500000US04013   04013  Maricopa County, Arizona             57964
# 2  0500000US04019   04019      Pima County, Arizona             23450
# 3  0500000US04021   04021     Pinal County, Arizona             13091
# 4  0500000US04027   04027      Yuma County, Arizona             11467
#
#                  HD02_VD01                    HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Less than $10,000
# 1                     3921                         2506
# 2                     2497                         3352
# 3                     2333                          929
# 4                     1659                         1306
#
#                             HD02_VD02                     HD01_VD03  \
# 0  Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999
# ...

# %%
census_other_2008_pd["Year"] = "2008"
census_other_2008_pd["Race"] = "Other"
census_other_2008_pd.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label         HD01_VD01  \
# 0              Id     Id2                 Geography  Estimate; Total:
# 1  0500000US04013   04013  Maricopa County, Arizona             57964
# 2  0500000US04019   04019      Pima County, Arizona             23450
# 3  0500000US04021   04021     Pinal County, Arizona             13091
# 4  0500000US04027   04027      Yuma County, Arizona             11467
#
#                  HD02_VD01                    HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Less than $10,000
# 1                     3921                         2506
# 2                     2497                         3352
# 3                     2333                          929
# 4                     1659                         1306
#
#                             HD02_VD02                     HD01_VD03  \
# 0  Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999
# ...

# %%
# Import the census data into a pandas DataFrame
census_other_2010_pd = pd.read_csv("census_data/Other/ACS_10_1YR_B19001F_with_ann.csv")

# Preview the data
census_other_2010_pd.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label         HD01_VD01  \
# 0              Id     Id2                 Geography  Estimate; Total:
# 1  0500000US04013   04013  Maricopa County, Arizona             56246
# 2  0500000US04019   04019      Pima County, Arizona             20608
# 3  0500000US04021   04021     Pinal County, Arizona              8153
# 4  0500000US04027   04027      Yuma County, Arizona              8409
#
#                  HD02_VD01                             HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Less than $10,000
# 1                     4244                                  5245
# 2                     2487                                  2228
# 3                     2062                                   734
# 4                     1454                                   813
#
#                                      HD02_VD02  \
# 0  Margin of Error; Total: - Less than $10,000
# 1                                         1240
# ...

# %%
census_other_2010_pd["Year"] = "2010"
census_other_2010_pd["Race"] = "Other"
census_other_2010_pd.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label         HD01_VD01  \
# 0              Id     Id2                 Geography  Estimate; Total:
# 1  0500000US04013   04013  Maricopa County, Arizona             56246
# 2  0500000US04019   04019      Pima County, Arizona             20608
# 3  0500000US04021   04021     Pinal County, Arizona              8153
# 4  0500000US04027   04027      Yuma County, Arizona              8409
#
#                  HD02_VD01                             HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Less than $10,000
# 1                     4244                                  5245
# 2                     2487                                  2228
# 3                     2062                                   734
# 4                     1454                                   813
#
#                                      HD02_VD02  \
# 0  Margin of Error; Total: - Less than $10,000
# 1                                         1240
# ...

# %%
# Import the census data into a pandas DataFrame
census_other_2013_pd = pd.read_csv("census_data/Other/ACS_13_1YR_B19001F_with_ann.csv")

# Preview the data
census_other_2013_pd.head()
# Out:
#            GEO.id GEO.id2           GEO.display-label         HD01_VD01  \
# 0              Id     Id2                   Geography  Estimate; Total:
# 1  0500000US04013   04013    Maricopa County, Arizona             59190
# 2  0500000US04019   04019        Pima County, Arizona             27378
# 3  0500000US04027   04027        Yuma County, Arizona              9411
# 4  0500000US06001   06001  Alameda County, California             32978
#
#                  HD02_VD01                             HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Less than $10,000
# 1                     3828                                  6127
# 2                     2232                                  3111
# 3                     1368                                   845
# 4                     2391                                   682
#
#                                      HD02_VD02  \
# 0  Margin of Error; Total: - Less than $10,000
# ...

# %%
census_other_2013_pd["Year"] = "2013"
census_other_2013_pd["Race"] = "Other"
census_other_2013_pd.head()
# Out:
#            GEO.id GEO.id2           GEO.display-label         HD01_VD01  \
# 0              Id     Id2                   Geography  Estimate; Total:
# 1  0500000US04013   04013    Maricopa County, Arizona             59190
# 2  0500000US04019   04019        Pima County, Arizona             27378
# 3  0500000US04027   04027        Yuma County, Arizona              9411
# 4  0500000US06001   06001  Alameda County, California             32978
#
#                  HD02_VD01                             HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Less than $10,000
# 1                     3828                                  6127
# 2                     2232                                  3111
# 3                     1368                                   845
# 4                     2391                                   682
#
#                                      HD02_VD02  \
# 0  Margin of Error; Total: - Less than $10,000
# ...

# %%
# Import the census data into a pandas DataFrame
census_other_2016_pd = pd.read_csv("census_data/Other/ACS_16_1YR_B19001F_with_ann.csv")

# Preview the data
census_other_2016_pd.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label         HD01_VD01  \
# 0              Id     Id2                 Geography  Estimate; Total:
# 1  0500000US04013   04013  Maricopa County, Arizona             93671
# 2  0500000US04019   04019      Pima County, Arizona             29588
# 3  0500000US04021   04021     Pinal County, Arizona              4167
# 4  0500000US04027   04027      Yuma County, Arizona             22780
#
#                  HD02_VD01                             HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Less than $10,000
# 1                     4023                                  8429
# 2                     2836                                  2536
# 3                     1066                                   244
# 4                     2113                                  1116
#
#                                      HD02_VD02  \
# 0  Margin of Error; Total: - Less than $10,000
# 1                                         1278
# ...

# %%
census_other_2016_pd["Year"] = "2016"
census_other_2016_pd["Race"] = "Other"
census_other_2016_pd.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label         HD01_VD01  \
# 0              Id     Id2                 Geography  Estimate; Total:
# 1  0500000US04013   04013  Maricopa County, Arizona             93671
# 2  0500000US04019   04019      Pima County, Arizona             29588
# 3  0500000US04021   04021     Pinal County, Arizona              4167
# 4  0500000US04027   04027      Yuma County, Arizona             22780
#
#                  HD02_VD01                             HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Less than $10,000
# 1                     4023                                  8429
# 2                     2836                                  2536
# 3                     1066                                   244
# 4                     2113                                  1116
#
#                                      HD02_VD02  \
# 0  Margin of Error; Total: - Less than $10,000
# 1                                         1278
# ...

# %%
# Concatenate dataframes
census_other_total_pd = pd.concat([census_other_2000_pd, census_other_2005_pd, census_other_2008_pd, census_other_2010_pd, census_other_2013_pd, census_other_2016_pd], ignore_index=True)
census_other_total_pd
# Out:
#                       GEO.display-label          GEO.id GEO.id2 HD01_VD01  \
# 0                             Geography              Id     Id2       NaN
# 1               Autauga County, Alabama  0500000US01001   01001       NaN
# 2               Baldwin County, Alabama  0500000US01003   01003       NaN
# 3               Barbour County, Alabama  0500000US01005   01005       NaN
# 4                  Bibb County, Alabama  0500000US01007   01007       NaN
# 5                Blount County, Alabama  0500000US01009   01009       NaN
# 6               Bullock County, Alabama  0500000US01011   01011       NaN
# 7                Butler County, Alabama  0500000US01013   01013       NaN
# 8               Calhoun County, Alabama  0500000US01015   01015       NaN
# 9              Chambers County, Alabama  0500000US01017   01017       NaN
# 10             Cherokee County, Alabama  0500000US01019   01019       NaN
# 11              Chilton County, Alabama  0500000US01021   01021       NaN
# ...

# %%
# Save Data to csv
census_other_total_pd.to_csv("census_data/census_other_total_pd.csv")
