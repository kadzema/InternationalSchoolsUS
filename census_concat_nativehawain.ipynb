# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time

# %%
# Import the census data into a pandas DataFrame
census_nativehawaiian_2000_pd = pd.read_csv("census_data/NativeHawaiian/DEC_00_SF3_P151E_with_ann.csv")

# Preview the data
census_nativehawaiian_2000_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama                 0
# 1  0500000US01003  1003  Baldwin County, Alabama                 8
# 2  0500000US01005  1005  Barbour County, Alabama                 0
# 3  0500000US01007  1007     Bibb County, Alabama                 0
# 4  0500000US01009  1009   Blount County, Alabama                13
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      NaN                                     0
# 1                      NaN                                     0
# 2                      NaN                                     0
# 3                      NaN                                     0
# 4                      NaN                                     0
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          NaN
# 1                                          NaN
# ...

# %%
census_nativehawaiian_2000_pd["Year"]="2000"
census_nativehawaiian_2000_pd["Race"]="NativeHawaiian"
census_nativehawaiian_2000_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama                 0
# 1  0500000US01003  1003  Baldwin County, Alabama                 8
# 2  0500000US01005  1005  Barbour County, Alabama                 0
# 3  0500000US01007  1007     Bibb County, Alabama                 0
# 4  0500000US01009  1009   Blount County, Alabama                13
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      NaN                                     0
# 1                      NaN                                     0
# 2                      NaN                                     0
# 3                      NaN                                     0
# 4                      NaN                                     0
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          NaN
# 1                                          NaN
# ...

# %%
# Import the census data into a pandas DataFrame
census_nativehawaiian_2005_pd = pd.read_csv("census_data/NativeHawaiian/ACS_05_EST_B19001E_with_ann.csv")

# Preview the data
census_nativehawaiian_2005_pd.head()
# Out:
#                Id    Id2                       Geography  Estimate; Total:  \
# 0  0500000US06037   6037  Los Angeles County, California              8890
# 1  0500000US15001  15001           Hawaii County, Hawaii              4489
# 2  0500000US15003  15003         Honolulu County, Hawaii             18774
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1315                                  1001
# 1                      868                                   478
# 2                     1822                                  1968
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          652
# 1                                          239
# 2                                          734
#
#    Estimate; Total: - $10,000 to $14,999  \
# 0                                    157
# 1                                    300
# 2                                   1198
#
# ...

# %%
census_nativehawaiian_2005_pd["Year"]="2005"
census_nativehawaiian_2005_pd["Race"]="NativeHawaiian"
census_nativehawaiian_2005_pd.head()
# Out:
#                Id    Id2                       Geography  Estimate; Total:  \
# 0  0500000US06037   6037  Los Angeles County, California              8890
# 1  0500000US15001  15001           Hawaii County, Hawaii              4489
# 2  0500000US15003  15003         Honolulu County, Hawaii             18774
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1315                                  1001
# 1                      868                                   478
# 2                     1822                                  1968
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          652
# 1                                          239
# 2                                          734
#
#    Estimate; Total: - $10,000 to $14,999  \
# 0                                    157
# 1                                    300
# 2                                   1198
#
# ...

# %%
# Import the census data into a pandas DataFrame
census_nativehawaiian_2008_pd = pd.read_csv("census_data/NativeHawaiian/ACS_08_1YR_B19001E_with_ann.csv")

# Preview the data
census_nativehawaiian_2008_pd.head()
# Out:
#                Id    Id2                       Geography  Estimate; Total:  \
# 0  0500000US06037   6037  Los Angeles County, California              7066
# 1  0500000US15001  15001           Hawaii County, Hawaii              5480
# 2  0500000US15003  15003         Honolulu County, Hawaii             19851
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1037                                   766
# 1                      877                                   474
# 2                     1474                                  1361
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          442
# 1                                          297
# 2                                          630
#
#    Estimate; Total: - $10,000 to $14,999  \
# 0                                    189
# 1                                    267
# 2                                    636
#
# ...

# %%
census_nativehawaiian_2008_pd["Year"]="2008"
census_nativehawaiian_2008_pd["Race"]="NativeHawaiian"
census_nativehawaiian_2008_pd.head()
# Out:
#                Id    Id2                       Geography  Estimate; Total:  \
# 0  0500000US06037   6037  Los Angeles County, California              7066
# 1  0500000US15001  15001           Hawaii County, Hawaii              5480
# 2  0500000US15003  15003         Honolulu County, Hawaii             19851
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1037                                   766
# 1                      877                                   474
# 2                     1474                                  1361
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          442
# 1                                          297
# 2                                          630
#
#    Estimate; Total: - $10,000 to $14,999  \
# 0                                    189
# 1                                    267
# 2                                    636
#
# ...

# %%
# Import the census data into a pandas DataFrame
census_nativehawaiian_2010_pd = pd.read_csv("census_data/NativeHawaiian/ACS_10_1YR_C19001E_with_ann.csv")

# Preview the data
census_nativehawaiian_2010_pd.head()
# Out:
#                Id    Id2                       Geography  Estimate; Total:  \
# 0  0500000US06001   6001      Alameda County, California              3175
# 1  0500000US06037   6037  Los Angeles County, California              6306
# 2  0500000US06067   6067   Sacramento County, California              3705
# 3  0500000US15001  15001           Hawaii County, Hawaii              5709
# 4  0500000US15003  15003         Honolulu County, Hawaii             20889
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      680                                   208
# 1                     1077                                   524
# 2                      727                                   211
# 3                      837                                   921
# 4                     1600                                  1016
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          259
# ...

# %%
census_nativehawaiian_2010_pd["Year"]="2010"
census_nativehawaiian_2010_pd["Race"]="NativeHawaiian"
census_nativehawaiian_2010_pd.head()
# Out:
#                Id    Id2                       Geography  Estimate; Total:  \
# 0  0500000US06001   6001      Alameda County, California              3175
# 1  0500000US06037   6037  Los Angeles County, California              6306
# 2  0500000US06067   6067   Sacramento County, California              3705
# 3  0500000US15001  15001           Hawaii County, Hawaii              5709
# 4  0500000US15003  15003         Honolulu County, Hawaii             20889
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      680                                   208
# 1                     1077                                   524
# 2                      727                                   211
# 3                      837                                   921
# 4                     1600                                  1016
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          259
# ...

# %%
# Import the census data into a pandas DataFrame
census_nativehawaiian_2013_pd = pd.read_csv("census_data/NativeHawaiian/ACS_13_1YR_B19001E_with_ann.csv")

# Preview the data
census_nativehawaiian_2013_pd.head()
# Out:
#                Id    Id2                       Geography  Estimate; Total:  \
# 0  0500000US06001   6001      Alameda County, California              3774
# 1  0500000US06037   6037  Los Angeles County, California              6601
# 2  0500000US15001  15001           Hawaii County, Hawaii              7264
# 3  0500000US15003  15003         Honolulu County, Hawaii             20922
# 4  0500000US15009  15009             Maui County, Hawaii              4651
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      689                                   217
# 1                     1076                                   340
# 2                     1200                                  1507
# 3                     1696                                  1557
# 4                      788                                   278
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          320
# ...

# %%
census_nativehawaiian_2013_pd["Year"]="2013"
census_nativehawaiian_2013_pd["Race"]="NativeHawaiian"
census_nativehawaiian_2013_pd.head()
# Out:
#                Id    Id2                       Geography  Estimate; Total:  \
# 0  0500000US06001   6001      Alameda County, California              3774
# 1  0500000US06037   6037  Los Angeles County, California              6601
# 2  0500000US15001  15001           Hawaii County, Hawaii              7264
# 3  0500000US15003  15003         Honolulu County, Hawaii             20922
# 4  0500000US15009  15009             Maui County, Hawaii              4651
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      689                                   217
# 1                     1076                                   340
# 2                     1200                                  1507
# 3                     1696                                  1557
# 4                      788                                   278
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          320
# ...

# %%
# Import the census data into a pandas DataFrame
census_nativehawaiian_2016_pd = pd.read_csv("census_data/NativeHawaiian/ACS_16_1YR_B19001E_with_ann.csv")

# Preview the data
census_nativehawaiian_2016_pd.head()
# Out:
#                Id    Id2                       Geography  Estimate; Total:  \
# 0  0500000US06037   6037  Los Angeles County, California              5967
# 1  0500000US15001  15001           Hawaii County, Hawaii              7535
# 2  0500000US15003  15003         Honolulu County, Hawaii             22345
# 3  0500000US15009  15009             Maui County, Hawaii              5636
# 4  0500000US32003  32003            Clark County, Nevada              4989
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      764                                   145
# 1                     1138                                   565
# 2                     1821                                  2011
# 3                      906                                   707
# 4                      846                                   571
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          180
# ...

# %%
census_nativehawaiian_2016_pd["Year"]="2016"
census_nativehawaiian_2016_pd["Race"]="NativeHawaiian"
census_nativehawaiian_2016_pd.head()
# Out:
#                Id    Id2                       Geography  Estimate; Total:  \
# 0  0500000US06037   6037  Los Angeles County, California              5967
# 1  0500000US15001  15001           Hawaii County, Hawaii              7535
# 2  0500000US15003  15003         Honolulu County, Hawaii             22345
# 3  0500000US15009  15009             Maui County, Hawaii              5636
# 4  0500000US32003  32003            Clark County, Nevada              4989
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      764                                   145
# 1                     1138                                   565
# 2                     1821                                  2011
# 3                      906                                   707
# 4                      846                                   571
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          180
# ...

# %%
# Concatenate dataframes]
census_nativehawain_total_pd = pd.concat([census_nativehawaiian_2000_pd, census_nativehawaiian_2005_pd,census_nativehawaiian_2008_pd, census_nativehawaiian_2010_pd, census_nativehawaiian_2013_pd, census_nativehawaiian_2016_pd], ignore_index=True)
census_nativehawain_total_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama                 0
# 1  0500000US01003  1003  Baldwin County, Alabama                 8
# 2  0500000US01005  1005  Barbour County, Alabama                 0
# 3  0500000US01007  1007     Bibb County, Alabama                 0
# 4  0500000US01009  1009   Blount County, Alabama                13
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      NaN                                     0
# 1                      NaN                                     0
# 2                      NaN                                     0
# 3                      NaN                                     0
# 4                      NaN                                     0
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          NaN
# 1                                          NaN
# ...

# %%
# Save Data to csv
census_nativehawain_total_pd.to_csv("census_data/census_nativehawain_total_pd.csv")
