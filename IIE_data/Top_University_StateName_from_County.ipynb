# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time

# %%
# Google API Key
gkey = "AIzaSyDq-O7AaN8YCmdhvXhax8Rh3ljxCH683xE"

# %%
# Import cities file as DataFrame
university_pd = pd.read_csv("university_county_09122017_Output.csv")
university_pd.head()
# Out:
#    Unnamed: 0               Place of Destination         City State Students  \
# 0           0                New York University     New York    NY   17,326
# 1           1  University of Southern California  Los Angeles    CA   14,327
# 2           2                Columbia University     New York    NY   14,096
# 3           3   Northeastern University - Boston       Boston    MA   13,201
# 4           4   Arizona State University - Tempe        Tempe    AZ   13,164
#
#    Year        Lat         Lng               County
# 0  2016  40.712775  -74.005973      New York County
# 1  2016  34.052234 -118.243685  Los Angeles  County
# 2  2016  40.712775  -74.005973      New York County
# 3  2016  42.360083  -71.058880      Suffolk  County
# 4  2016  33.425510 -111.940005     Maricopa  County

# %%
# Add column for State Name to Match census syntax
university_pd["State"] = ""
university_pd.head()
# Out:
#    Unnamed: 0               Place of Destination         City State Students  \
# 0           0                New York University     New York         17,326
# 1           1  University of Southern California  Los Angeles         14,327
# 2           2                Columbia University     New York         14,096
# 3           3   Northeastern University - Boston       Boston         13,201
# 4           4   Arizona State University - Tempe        Tempe         13,164
#
#    Year        Lat         Lng               County
# 0  2016  40.712775  -74.005973      New York County
# 1  2016  34.052234 -118.243685  Los Angeles  County
# 2  2016  40.712775  -74.005973      New York County
# 3  2016  42.360083  -71.058880      Suffolk  County
# 4  2016  33.425510 -111.940005     Maricopa  County

# %%
# Acquire State of each County
for index, row in university_pd.iterrows():
    state = row["State"]

    # Counter
    row_count = 0

    # URL county name
    target_url = "https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=%s" % (row["City"], gkey)
#     print(urllib.parse.urlencode(target_url))

    # Print log to ensure loop is working correctly
    print("Retrieving State name " + str(row_count))
    print(target_url)
    row_count += 1
    
    # Run requests to grab the JSON at the requested URL
    state_name = requests.get(target_url).json()
    
    # Append county names to County column
    # Use try / except to skip any cities with errors
    try:        
        State = state_name["results"][0]["address_components"][2]["long_name"]
        
        university_pd.set_value(index, "State", State)        
    
    except:
        print("Missing field... skipping.")
# Out:
# Retrieving State name 0
# https://maps.googleapis.com/maps/api/geocode/json?address=New York&key=AIzaSyDq-O7AaN8YCmdhvXhax8Rh3ljxCH683xE
# Retrieving State name 0
# https://maps.googleapis.com/maps/api/geocode/json?address=Los Angeles&key=AIzaSyDq-O7AaN8YCmdhvXhax8Rh3ljxCH683xE
# Retrieving State name 0
# https://maps.googleapis.com/maps/api/geocode/json?address=New York&key=AIzaSyDq-O7AaN8YCmdhvXhax8Rh3ljxCH683xE
# Retrieving State name 0
# https://maps.googleapis.com/maps/api/geocode/json?address=Boston&key=AIzaSyDq-O7AaN8YCmdhvXhax8Rh3ljxCH683xE
# Retrieving State name 0
# https://maps.googleapis.com/maps/api/geocode/json?address=Tempe&key=AIzaSyDq-O7AaN8YCmdhvXhax8Rh3ljxCH683xE
# Retrieving State name 0
# https://maps.googleapis.com/maps/api/geocode/json?address=Champaign&key=AIzaSyDq-O7AaN8YCmdhvXhax8Rh3ljxCH683xE
# Retrieving State name 0
# https://maps.googleapis.com/maps/api/geocode/json?address=Los Angeles&key=AIzaSyDq-O7AaN8YCmdhvXhax8Rh3ljxCH683xE
# ...

# %%
university_pd.head()
# Out:
#    Unnamed: 0               Place of Destination         City          State  \
# 0           0                New York University     New York  United States
# 1           1  University of Southern California  Los Angeles     California
# 2           2                Columbia University     New York  United States
# 3           3   Northeastern University - Boston       Boston  Massachusetts
# 4           4   Arizona State University - Tempe        Tempe        Arizona
#
#   Students  Year        Lat         Lng               County County_Name
# 0   17,326  2016  40.712775  -74.005973      New York County
# 1   14,327  2016  34.052234 -118.243685  Los Angeles  County
# 2   14,096  2016  40.712775  -74.005973      New York County
# 3   13,201  2016  42.360083  -71.058880      Suffolk  County
# 4   13,164  2016  33.425510 -111.940005     Maricopa  County

# %%
# Add column for Concatenated Name to Match census syntax
university_pd["County_Name"] = ""
university_pd.head()
# Out:
#    Unnamed: 0               Place of Destination         City          State  \
# 0           0                New York University     New York  United States
# 1           1  University of Southern California  Los Angeles     California
# 2           2                Columbia University     New York  United States
# 3           3   Northeastern University - Boston       Boston  Massachusetts
# 4           4   Arizona State University - Tempe        Tempe        Arizona
#
#   Students  Year        Lat         Lng               County County_Name
# 0   17,326  2016  40.712775  -74.005973      New York County
# 1   14,327  2016  34.052234 -118.243685  Los Angeles  County
# 2   14,096  2016  40.712775  -74.005973      New York County
# 3   13,201  2016  42.360083  -71.058880      Suffolk  County
# 4   13,164  2016  33.425510 -111.940005     Maricopa  County

# %%
university_pd['County_Name'] = university_pd['County'] + ', ' + university_pd['State']
university_pd.head()
# Out:
#    Unnamed: 0               Place of Destination         City          State  \
# 0           0                New York University     New York  United States
# 1           1  University of Southern California  Los Angeles     California
# 2           2                Columbia University     New York  United States
# 3           3   Northeastern University - Boston       Boston  Massachusetts
# 4           4   Arizona State University - Tempe        Tempe        Arizona
#
#   Students  Year        Lat         Lng               County  \
# 0   17,326  2016  40.712775  -74.005973      New York County
# 1   14,327  2016  34.052234 -118.243685  Los Angeles  County
# 2   14,096  2016  40.712775  -74.005973      New York County
# 3   13,201  2016  42.360083  -71.058880      Suffolk  County
# 4   13,164  2016  33.425510 -111.940005     Maricopa  County
#
#                        County_Name
# 0   New York County, United States
# 1  Los Angeles  County, California
# ...

# %%
# Save Data to csv
university_pd.to_csv("university_county_state_11122017_Output.csv", encoding="utf-8")
