# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time

# %%
# Import the census data into a pandas DataFrame
census_other_2000_pd = pd.read_csv("census_data/Other/2000_other_cleaned.csv")

# Preview the data
census_other_2000_pd.head()
# Out:
#    CountyID               CountyName  TotalPopulation  Less than $10,000  \
# 0      1001  Autauga County, Alabama               31                  7
# 1      1003  Baldwin County, Alabama              212                 22
# 2      1005  Barbour County, Alabama               57                 10
# 3      1007     Bibb County, Alabama               15                  0
# 4      1009   Blount County, Alabama              307                 42
#
#    $10,000 to $14,999  $15,000 to $19,999  $20,000 to $24,999  \
# 0                   0                   0                   8
# 1                  31                   5                  36
# 2                  10                   2                   0
# 3                   0                   0                   0
# 4                  17                  15                  27
#
#    $25,000 to $29,999  $30,000 to $34,999  $35,000 to $39,999  ...    \
# 0                   0                   0                   0  ...
# ...

# %%
# Import the census data into a pandas DataFrame
census_other_2005_pd = pd.read_csv("census_data/Other/2005_other_cleaned.csv")

# Preview the data
census_other_2005_pd.head()
# Out:
#    CountyID                  CountyName  TotalPopulation  Less than $10,000  \
# 0      4013    Maricopa County, Arizona           101811               6562
# 1      4019        Pima County, Arizona            46916               4345
# 2      4021       Pinal County, Arizona            10177               1102
# 3      4027        Yuma County, Arizona            11391               2547
# 4      6001  Alameda County, California            40081               2383
#
#    $10,000 to $14,999  $15,000 to $19,999  $20,000 to $24,999  \
# 0                7316                7081                8596
# 1                3923                3813                4219
# 2                 829                1378                 862
# 3                 825                 367                 734
# 4                1709                1048                2812
#
#    $25,000 to $29,999  $30,000 to $34,999  $35,000 to $39,999  ...    \
# ...

# %%
# Import the census data into a pandas DataFrame
census_other_2008_pd = pd.read_csv("census_data/Other/2008_other_cleaned.csv")

# Preview the data
census_other_2008_pd.head()
# Out:
#    CountyID                  CountyName  TotalPopulation  Less than $10,000  \
# 0      4013    Maricopa County, Arizona            57964               2506
# 1      4019        Pima County, Arizona            23450               3352
# 2      4021       Pinal County, Arizona            13091                929
# 3      4027        Yuma County, Arizona            11467               1306
# 4      6001  Alameda County, California            33345               1461
#
#    $10,000 to $14,999  $15,000 to $19,999  $20,000 to $24,999  \
# 0                2129                3169                2489
# 1                2274                1605                1738
# 2                 456                1353                1113
# 3                1034                 815                 945
# 4                1761                2372                1536
#
#    $25,000 to $29,999  $30,000 to $34,999  $35,000 to $39,999  ...    \
# ...

# %%
# Import the census data into a pandas DataFrame
census_other_2010_pd = pd.read_csv("census_data/Other/2010_other_cleaned.csv")

# Preview the data
census_other_2010_pd.head()
# Out:
#    CountyID                  CountyName  TotalPopulation  Less than $10,000  \
# 0      4013    Maricopa County, Arizona            56246               5245
# 1      4019        Pima County, Arizona            20608               2228
# 2      4021       Pinal County, Arizona             8153                734
# 3      4027        Yuma County, Arizona             8409                813
# 4      6001  Alameda County, California            31922               1248
#
#    $10,000 to $14,999  $15,000 to $19,999  $20,000 to $24,999  \
# 0                3236                3785                4259
# 1                2543                1257                2186
# 2                1172                   0                 715
# 3                 372                 467                 864
# 4                2245                1530                2297
#
#    $25,000 to $29,999  $30,000 to $34,999  $35,000 to $39,999  ...    \
# ...

# %%
# Import the census data into a pandas DataFrame
census_other_2013_pd = pd.read_csv("census_data/Other/2013_other_cleaned.csv")

# Preview the data
census_other_2013_pd.head()
# Out:
#    CountyID                       CountyName  TotalPopulation  \
# 0      4013         Maricopa County, Arizona            59190
# 1      4019             Pima County, Arizona            27378
# 2      4027             Yuma County, Arizona             9411
# 3      6001       Alameda County, California            32978
# 4      6013  Contra Costa County, California            20873
#
#    Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 0               6127                3047                4771
# 1               3111                2768                2787
# 2                845                 601                 551
# 3                682                 835                1768
# 4                786                 462                1723
#
#    $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 0                5876                3294                4064
# 1                2692                3624                1501
# ...

# %%
# Import the census data into a pandas DataFrame
census_other_2016_pd = pd.read_csv("census_data/Other/2016_other_cleaned.csv")

# Preview the data
census_other_2016_pd.head()
# Out:
#    CountyID                  CountyName  TotalPopulation  Less than $10,000  \
# 0      4013    Maricopa County, Arizona            93671               8429
# 1      4019        Pima County, Arizona            29588               2536
# 2      4021       Pinal County, Arizona             4167                244
# 3      4027        Yuma County, Arizona            22780               1116
# 4      6001  Alameda County, California            41898               1650
#
#    $10,000 to $14,999  $15,000 to $19,999  $20,000 to $24,999  \
# 0                5754                5011                5977
# 1                2822                3025                2267
# 2                 582                 238                 452
# 3                1306                1918                1018
# 4                1709                 989                1537
#
#    $25,000 to $29,999  $30,000 to $34,999  $35,000 to $39,999  ...    \
# ...

# %%
# Concatenate dataframes
census_other_total_pd = pd.concat([census_other_2000_pd, census_other_2005_pd, census_other_2008_pd, census_other_2010_pd, census_other_2013_pd, census_other_2016_pd], ignore_index=True)
census_other_total_pd
# Out:
#       CountyID                         CountyName  TotalPopulation  \
# 0         1001            Autauga County, Alabama               31
# 1         1003            Baldwin County, Alabama              212
# 2         1005            Barbour County, Alabama               57
# 3         1007               Bibb County, Alabama               15
# 4         1009             Blount County, Alabama              307
# 5         1011            Bullock County, Alabama                5
# 6         1013             Butler County, Alabama                4
# 7         1015            Calhoun County, Alabama              143
# 8         1017           Chambers County, Alabama               26
# 9         1019           Cherokee County, Alabama               16
# 10        1021            Chilton County, Alabama              102
# 11        1023            Choctaw County, Alabama                5
# 12        1025             Clarke County, Alabama               11
# ...

# %%
# Save Data to csv
census_other_total_pd.to_csv("census_data/census_other_total_cleaned_pd.csv")
