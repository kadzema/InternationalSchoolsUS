# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time

# %%
# Import the census data into a pandas DataFrame
census_black_2000_pd = pd.read_csv("census_data/Black/DEC_00_SF3_P151B_with_ann.csv")

# Preview the data
#census_black_2000_pd.head()

# %%
census_black_2000_pd["Year"] = "2000"
census_black_2000_pd["Race"] = "Black"
census_black_2000_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama              2566
# 1  0500000US01003  1003  Baldwin County, Alabama              4650
# 2  0500000US01005  1005  Barbour County, Alabama              4446
# 3  0500000US01007  1007     Bibb County, Alabama              1306
# 4  0500000US01009  1009   Blount County, Alabama               146
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      NaN                                   617
# 1                      NaN                                   940
# 2                      NaN                                  1553
# 3                      NaN                                   508
# 4                      NaN                                    46
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          NaN
# 1                                          NaN
# ...

# %%
# Import the census data into a pandas DataFrame
census_black_2005_pd = pd.read_csv("census_data/Black/ACS_05_EST_B19001B_with_ann.csv")

# Preview the data
census_black_2005_pd.head()
# Out:
#                Id   Id2                  Geography  Estimate; Total:  \
# 0  0500000US01015  1015    Calhoun County, Alabama              9092
# 1  0500000US01055  1055     Etowah County, Alabama              6030
# 2  0500000US01069  1069    Houston County, Alabama              9421
# 3  0500000US01073  1073  Jefferson County, Alabama            101964
# 4  0500000US01081  1081        Lee County, Alabama             10910
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      876                                  2192
# 1                      636                                  1486
# 2                      510                                  2492
# 3                     2366                                 17190
# 4                      761                                  2591
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          762
# 1                                          523
# ...

# %%
census_black_2005_pd["Year"] = "2005"
census_black_2005_pd["Race"] = "Black"
census_black_2005_pd.head()
# Out:
#                Id   Id2                  Geography  Estimate; Total:  \
# 0  0500000US01015  1015    Calhoun County, Alabama              9092
# 1  0500000US01055  1055     Etowah County, Alabama              6030
# 2  0500000US01069  1069    Houston County, Alabama              9421
# 3  0500000US01073  1073  Jefferson County, Alabama            101964
# 4  0500000US01081  1081        Lee County, Alabama             10910
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      876                                  2192
# 1                      636                                  1486
# 2                      510                                  2492
# 3                     2366                                 17190
# 4                      761                                  2591
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          762
# 1                                          523
# ...

# %%
# Import the census data into a pandas DataFrame
census_black_2008_pd = pd.read_csv("census_data/Black/ACS_08_1YR_B19001B_with_ann.csv")

# Preview the data
census_black_2008_pd.head()
# Out:
#                Id   Id2                  Geography  Estimate; Total:  \
# 0  0500000US01015  1015    Calhoun County, Alabama              8730
# 1  0500000US01055  1055     Etowah County, Alabama              6483
# 2  0500000US01069  1069    Houston County, Alabama              8420
# 3  0500000US01073  1073  Jefferson County, Alabama            104361
# 4  0500000US01081  1081        Lee County, Alabama             11832
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1008                                  1681
# 1                      807                                  1390
# 2                      600                                  1430
# 3                     2724                                 12700
# 4                     1150                                  1970
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          601
# 1                                          623
# ...

# %%
census_black_2008_pd["Year"] = "2008"
census_black_2008_pd["Race"] = "Black"
census_black_2008_pd.head()
# Out:
#                Id   Id2                  Geography  Estimate; Total:  \
# 0  0500000US01015  1015    Calhoun County, Alabama              8730
# 1  0500000US01055  1055     Etowah County, Alabama              6483
# 2  0500000US01069  1069    Houston County, Alabama              8420
# 3  0500000US01073  1073  Jefferson County, Alabama            104361
# 4  0500000US01081  1081        Lee County, Alabama             11832
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1008                                  1681
# 1                      807                                  1390
# 2                      600                                  1430
# 3                     2724                                 12700
# 4                     1150                                  1970
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          601
# 1                                          623
# ...

# %%
# Import the census data into a pandas DataFrame
census_black_2010_pd = pd.read_csv("census_data/Black/ACS_10_1YR_B19001B_with_ann.csv")

# Preview the data
census_black_2010_pd.head()
# Out:
#                Id   Id2                  Geography  Estimate; Total:  \
# 0  0500000US01015  1015    Calhoun County, Alabama              8308
# 1  0500000US01055  1055     Etowah County, Alabama              5363
# 2  0500000US01069  1069    Houston County, Alabama              9911
# 3  0500000US01073  1073  Jefferson County, Alabama            104711
# 4  0500000US01081  1081        Lee County, Alabama             12559
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1284                                  2399
# 1                      641                                   483
# 2                      508                                  2082
# 3                     2757                                 18537
# 4                      819                                  2426
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          761
# 1                                          300
# ...

# %%
census_black_2010_pd["Year"] = "2010"
census_black_2010_pd["Race"] = "Black"
census_black_2010_pd.head()
# Out:
#                Id   Id2                  Geography  Estimate; Total:  \
# 0  0500000US01015  1015    Calhoun County, Alabama              8308
# 1  0500000US01055  1055     Etowah County, Alabama              5363
# 2  0500000US01069  1069    Houston County, Alabama              9911
# 3  0500000US01073  1073  Jefferson County, Alabama            104711
# 4  0500000US01081  1081        Lee County, Alabama             12559
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1284                                  2399
# 1                      641                                   483
# 2                      508                                  2082
# 3                     2757                                 18537
# 4                      819                                  2426
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          761
# 1                                          300
# ...

# %%
# Import the census data into a pandas DataFrame
census_black_2013_pd = pd.read_csv("census_data/Black/ACS_13_1YR_B19001B_with_ann.csv")
census_black_2013_pd["Year"] = "2013"
census_black_2013_pd["Race"] = "Black"
census_black_2013_pd.head()
# Out:
#                Id   Id2                  Geography  Estimate; Total:  \
# 0  0500000US01015  1015    Calhoun County, Alabama              9027
# 1  0500000US01051  1051     Elmore County, Alabama              5133
# 2  0500000US01055  1055     Etowah County, Alabama              6707
# 3  0500000US01069  1069    Houston County, Alabama              9872
# 4  0500000US01073  1073  Jefferson County, Alabama            105789
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      958                                  1889
# 1                      907                                   741
# 2                      676                                   902
# 3                      504                                  1997
# 4                     2964                                 17624
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          772
# 1                                          505
# ...

# %%
# Import the census data into a pandas DataFrame
census_black_2016_pd = pd.read_csv("census_data/Black/ACS_16_1YR_B19001B_with_ann.csv")
census_black_2016_pd.head()
census_black_2016_pd["Year"] = "2016"
census_black_2016_pd["Race"] = "Black"
census_black_2016_pd.head()
# Out:
#                Id   Id2                  Geography  Estimate; Total:  \
# 0  0500000US01015  1015    Calhoun County, Alabama              8912
# 1  0500000US01055  1055     Etowah County, Alabama              6146
# 2  0500000US01069  1069    Houston County, Alabama             10353
# 3  0500000US01073  1073  Jefferson County, Alabama            109168
# 4  0500000US01081  1081        Lee County, Alabama             14654
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      889                                   953
# 1                      763                                  1298
# 2                      657                                  1725
# 3                     3317                                 15187
# 4                     1218                                  1893
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          421
# 1                                          553
# ...

# %%
# Concatenate dataframes]
census_black_total_pd = pd.concat([census_black_2000_pd, census_black_2005_pd,census_black_2008_pd, census_black_2010_pd, census_black_2013_pd, census_black_2016_pd], ignore_index=True)
census_black_total_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama              2566
# 1  0500000US01003  1003  Baldwin County, Alabama              4650
# 2  0500000US01005  1005  Barbour County, Alabama              4446
# 3  0500000US01007  1007     Bibb County, Alabama              1306
# 4  0500000US01009  1009   Blount County, Alabama               146
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      NaN                                   617
# 1                      NaN                                   940
# 2                      NaN                                  1553
# 3                      NaN                                   508
# 4                      NaN                                    46
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          NaN
# 1                                          NaN
# ...

# %%
# Save Data to csv
census_black_total_pd.to_csv("census_data/census_black_total_pd.csv")
