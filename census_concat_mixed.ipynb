# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time

# %%
# Import the census data into a pandas DataFrame
census_mixed_2000_pd = pd.read_csv("census_data/Mixed/DEC_00_SF3_P151G_with_ann.csv")

# Preview the data
census_mixed_2000_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama               171
# 1  0500000US01003  1003  Baldwin County, Alabama               566
# 2  0500000US01005  1005  Barbour County, Alabama                75
# 3  0500000US01007  1007     Bibb County, Alabama                61
# 4  0500000US01009  1009   Blount County, Alabama               183
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      NaN                                    21
# 1                      NaN                                    47
# 2                      NaN                                    18
# 3                      NaN                                     2
# 4                      NaN                                    17
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          NaN
# 1                                          NaN
# ...

# %%
census_mixed_2000_pd["Year"]="2000"
census_mixed_2000_pd["Race"]="Mixed"
census_mixed_2000_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama               171
# 1  0500000US01003  1003  Baldwin County, Alabama               566
# 2  0500000US01005  1005  Barbour County, Alabama                75
# 3  0500000US01007  1007     Bibb County, Alabama                61
# 4  0500000US01009  1009   Blount County, Alabama               183
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      NaN                                    21
# 1                      NaN                                    47
# 2                      NaN                                    18
# 3                      NaN                                     2
# 4                      NaN                                    17
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          NaN
# 1                                          NaN
# ...

# %%
# Import the census data into a pandas DataFrame
census_mixed_2005_pd = pd.read_csv("census_data/Mixed/ACS_05_EST_B19001G_with_ann.csv")

# Preview the data
census_mixed_2005_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              4948
# 1  0500000US04013  4013         Maricopa County, Arizona             16799
# 2  0500000US04019  4019             Pima County, Arizona              5852
# 3  0500000US06001  6001       Alameda County, California             13647
# 4  0500000US06013  6013  Contra Costa County, California              8948
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1057                                   433
# 1                     2136                                  1057
# 2                     1136                                   787
# 3                     1695                                   993
# 4                     1522                                   471
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          308
# ...

# %%
census_mixed_2005_pd["Year"]="2005"
census_mixed_2005_pd["Race"]="Mixed"
census_mixed_2005_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              4948
# 1  0500000US04013  4013         Maricopa County, Arizona             16799
# 2  0500000US04019  4019             Pima County, Arizona              5852
# 3  0500000US06001  6001       Alameda County, California             13647
# 4  0500000US06013  6013  Contra Costa County, California              8948
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1057                                   433
# 1                     2136                                  1057
# 2                     1136                                   787
# 3                     1695                                   993
# 4                     1522                                   471
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          308
# ...

# %%
# Import the census data into a pandas DataFrame
census_mixed_2008_pd = pd.read_csv("census_data/Mixed/ACS_08_1YR_B19001G_with_ann.csv")

# Preview the data
census_mixed_2008_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              6681
# 1  0500000US04013  4013         Maricopa County, Arizona             19427
# 2  0500000US04019  4019             Pima County, Arizona              5637
# 3  0500000US06001  6001       Alameda County, California             14306
# 4  0500000US06013  6013  Contra Costa County, California              9373
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1422                                    33
# 1                     2048                                  1317
# 2                     1161                                   482
# 3                     1871                                  1229
# 4                     1391                                   710
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                           61
# ...

# %%
census_mixed_2008_pd["Year"]="2008"
census_mixed_2008_pd["Race"]="Mixed"
census_mixed_2008_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              6681
# 1  0500000US04013  4013         Maricopa County, Arizona             19427
# 2  0500000US04019  4019             Pima County, Arizona              5637
# 3  0500000US06001  6001       Alameda County, California             14306
# 4  0500000US06013  6013  Contra Costa County, California              9373
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1422                                    33
# 1                     2048                                  1317
# 2                     1161                                   482
# 3                     1871                                  1229
# 4                     1391                                   710
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                           61
# ...

# %%
# Import the census data into a pandas DataFrame
census_mixed_2010_pd = pd.read_csv("census_data/Mixed/ACS_10_1YR_B19001G_with_ann.csv")

# Preview the data
census_mixed_2010_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              5606
# 1  0500000US04013  4013         Maricopa County, Arizona             20548
# 2  0500000US04019  4019             Pima County, Arizona              6445
# 3  0500000US06001  6001       Alameda County, California             20072
# 4  0500000US06013  6013  Contra Costa County, California             10358
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1108                                   139
# 1                     2195                                  1314
# 2                     1140                                   763
# 3                     2383                                  1538
# 4                     1552                                   382
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          181
# ...

# %%
census_mixed_2010_pd["Year"]="2010"
census_mixed_2010_pd["Race"]="Mixed"
census_mixed_2010_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              5606
# 1  0500000US04013  4013         Maricopa County, Arizona             20548
# 2  0500000US04019  4019             Pima County, Arizona              6445
# 3  0500000US06001  6001       Alameda County, California             20072
# 4  0500000US06013  6013  Contra Costa County, California             10358
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1108                                   139
# 1                     2195                                  1314
# 2                     1140                                   763
# 3                     2383                                  1538
# 4                     1552                                   382
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          181
# ...

# %%
# Import the census data into a pandas DataFrame
census_mixed_2013_pd = pd.read_csv("census_data/Mixed/ACS_13_1YR_B19001G_with_ann.csv")

# Preview the data
census_mixed_2013_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US04013  4013         Maricopa County, Arizona             25246
# 1  0500000US04019  4019             Pima County, Arizona              9347
# 2  0500000US06001  6001       Alameda County, California             21893
# 3  0500000US06013  6013  Contra Costa County, California             14060
# 4  0500000US06019  6019        Fresno County, California              7112
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     2390                                  2497
# 1                     1389                                  1196
# 2                     2167                                  2216
# 3                     2003                                   543
# 4                     1045                                   993
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          793
# ...

# %%
census_mixed_2013_pd["Year"]="2013"
census_mixed_2013_pd["Race"]="Mixed"
census_mixed_2013_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US04013  4013         Maricopa County, Arizona             25246
# 1  0500000US04019  4019             Pima County, Arizona              9347
# 2  0500000US06001  6001       Alameda County, California             21893
# 3  0500000US06013  6013  Contra Costa County, California             14060
# 4  0500000US06019  6019        Fresno County, California              7112
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     2390                                  2497
# 1                     1389                                  1196
# 2                     2167                                  2216
# 3                     2003                                   543
# 4                     1045                                   993
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          793
# ...

# %%
# Import the census data into a pandas DataFrame
census_mixed_2016_pd = pd.read_csv("census_data/Mixed/ACS_16_1YR_B19001G_with_ann.csv")

# Preview the data
census_mixed_2016_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              6009
# 1  0500000US04013  4013         Maricopa County, Arizona             32076
# 2  0500000US04019  4019             Pima County, Arizona             12915
# 3  0500000US06001  6001       Alameda County, California             24065
# 4  0500000US06013  6013  Contra Costa County, California             20190
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1040                                   142
# 1                     2968                                  2415
# 2                     2008                                   837
# 3                     2129                                   822
# 4                     2171                                  1709
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          177
# ...

# %%
census_mixed_2016_pd["Year"]="2016"
census_mixed_2016_pd["Race"]="Mixed"
census_mixed_2016_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              6009
# 1  0500000US04013  4013         Maricopa County, Arizona             32076
# 2  0500000US04019  4019             Pima County, Arizona             12915
# 3  0500000US06001  6001       Alameda County, California             24065
# 4  0500000US06013  6013  Contra Costa County, California             20190
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                     1040                                   142
# 1                     2968                                  2415
# 2                     2008                                   837
# 3                     2129                                   822
# 4                     2171                                  1709
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          177
# ...

# %%
# Concatenate dataframes
census_mixed_total_pd = pd.concat([census_mixed_2000_pd, census_mixed_2005_pd, census_mixed_2008_pd, census_mixed_2010_pd, census_mixed_2013_pd, census_mixed_2016_pd], ignore_index=True)
census_mixed_total_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama               171
# 1  0500000US01003  1003  Baldwin County, Alabama               566
# 2  0500000US01005  1005  Barbour County, Alabama                75
# 3  0500000US01007  1007     Bibb County, Alabama                61
# 4  0500000US01009  1009   Blount County, Alabama               183
#
#    Margin of Error; Total:  Estimate; Total: - Less than $10,000  \
# 0                      NaN                                    21
# 1                      NaN                                    47
# 2                      NaN                                    18
# 3                      NaN                                     2
# 4                      NaN                                    17
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                          NaN
# 1                                          NaN
# ...

# %%
# Save Data to csv
census_mixed_total_pd.to_csv("census_data/census_mixed_total_pd.csv")
