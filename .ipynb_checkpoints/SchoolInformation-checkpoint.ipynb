# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time

key='AIzaSyBIqDXw_KeEU9cWBneQk5MvB7qgLsBlIrY'

# %%
# Import the census data into a pandas DataFrame
census_latlng_pd = pd.read_csv("census_data/census_counties_lat_lng.csv")

# Preview the data
census_latlng_pd.head()
# Out:
#    Unnamed: 0                        Geography              Id   Id2  \
# 0           0         Maricopa County, Arizona  0500000US04013  4013
# 1           1             Pima County, Arizona  0500000US04019  4019
# 2           2       Alameda County, California  0500000US06001  6001
# 3           3  Contra Costa County, California  0500000US06013  6013
# 4           4        Fresno County, California  0500000US06019  6019
#
#          Lat        Lng
# 0  30.601074 -87.776333
# 1  33.770158 -85.807660
# 2  34.201154 -86.822034
# 3  34.521140 -85.684578
# 4  32.564708 -86.012157

# %%
#Count of counties including duplicate
census_latlng_pd.count()
# Out:
# Unnamed: 0    1803
# Geography     1803
# Id            1803
# Id2           1803
# Lat           1803
# Lng           1803
# dtype: int64

# %%
# Unique count of counties via Id

census_latlng_pd=census_latlng_pd.drop_duplicates(subset='Id', keep='last')
census_latlng_pd.count()
# Out:
# Unnamed: 0    818
# Geography     818
# Id            818
# Id2           818
# Lat           818
# Lng           818
# dtype: int64

# %%
# Renaming the column and deleting extra column

census_latlng_pd=census_latlng_pd.drop(['Id2'],axis=1)
census_latlng_pd = census_latlng_pd.rename(columns={'Geography': 'CountyName'})
census_latlng_pd.head()
# Out:
#      Unnamed: 0               CountyName              Id        Lat        Lng
# 985           0  Baldwin County, Alabama  0500000US01003  30.601074 -87.776333
# 986           1  Calhoun County, Alabama  0500000US01015  33.770158 -85.807660
# 987           2  Cullman County, Alabama  0500000US01043  34.201154 -86.822034
# 988           3   DeKalb County, Alabama  0500000US01049  34.521140 -85.684578
# 989           4   Elmore County, Alabama  0500000US01051  32.564708 -86.012157

# %%
#Looping through the each lat and lng in dataframe

for index, row in census_latlng_pd.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]

#build the url with the google API

url=https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-33.8670522,151.1957362&radius=500&type=restaurant&keyword=cruise&key=AIzaSyBIqDXw_KeEU9cWBneQk5MvB7qgLsBlIrY
# Out:
# 30.6010744 -87.7763333
# 33.7701576 -85.80766
# 34.2011537 -86.8220341
# 34.521139700000006 -85.684578
# 32.5647083 -86.0121573
# 34.045534100000005 -86.0529604
# 31.131868599999997 -85.31362179999999
# 33.4914122 -86.9824288
# 34.8840876 -87.658113
# 32.5888702 -85.3962769
# 34.78000720000001 -86.9423801
# 34.7239731 -86.4996546
# 34.3652297 -86.3376761
# 30.608222700000002 -88.24611829999999
# 32.2077447 -86.17517590000001
# 34.4240875 -86.8621827
# 33.6530112 -86.3376761
# 33.3039292 -86.6611083
# 33.4231716 -86.13446970000001
# 33.3227653 -87.460397
# 33.8563605 -87.30161319999999
# 61.2180556 -149.90027780000003
# 64.95261020000001 -146.4744154
# 62.25993470000001 -150.17291530000003
# 31.828458 -109.94968600000001
# 35.6647545 -111.47528510000001
# 33.2917968 -112.42914640000002
# 35.2143346 -113.7632828
# 35.4019765 -110.1402594
# 32.057499 -111.66607250000001
# 32.816206099999995 -111.28450249999999
# 34.646398100000006 -112.42914640000002
# 32.6527533 -113.9536466
# ...
