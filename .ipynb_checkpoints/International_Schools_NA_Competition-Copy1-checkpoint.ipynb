# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time
# Google Places API Key
gkey = ""

# %%
# Import the census data into a pandas DataFrame
census_total_pd = pd.read_csv("census_total_2016_geo.csv")

# Preview the data
census_total_pd.head()
# Out:
#    Unnamed: 0  $10,000 to $14,999  $100,000 to $124,999  $125,000 to $149,999  \
# 0           0                 531                  4291                  3147
# 1           1                 178                   572                   297
# 2           2                2833                 14788                 11286
# 3           3                 500                  5407                  3342
# 4           4                1347                  1010                  1228
#
#    $15,000 to $19,999  $150,000 to $199,999  $20,000 to $24,999  \
# 0                1267                  4105                1326
# 1                 112                   508                 236
# 2                2479                 18340                2375
# 3                 648                  6547                 724
# 4                1229                  1029                 904
#
#    $200,000 or more  $25,000 to $29,999  $30,000 to $34,999    ...      \
# ...

# %%
# Count of unique counties via Id2
# census_total_pd.groupby("Id2").nunique()

# %%
# Use the lat/lng we recovered to identify schools
for index, row in census_total_pd.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
                
# Visualize to confirm lat lng appear
# Create an empty column for school count
census_total_pd["School Count"] = ""

# Counter
row_count = 0

# Loop through and run Google search to get all banks in 7 mile radius (11000 meters)
for index, row in census_total_pd.iterrows():
    
    # Create endpoint url using Google Places Radar and the lat/lng we identified earlier
    target_url ="https://maps.googleapis.com/maps/api/place/radarsearch/json?location=%s,%s&radius=11000&keyword=international+school&key=%s" % (census_total_pd.loc[index]["Lat"], census_total_pd.loc[index]["Lng"], gkey)

    
    # This link helps to handily see the JSON generated for each query
    print("Now retrieving county #%s: %s" % (row_count, census_total_pd.loc[index]["Geography"]))
    row_count += 1 
    print(target_url)
    
    # Run a request to grab the JSON at the target URL
    school_data = requests.get(target_url).json()
    
    # Measure school count on the number of results in the retrieved area
    school_count = len(school_data["results"])
    
    print("Final School Count: " + str(school_count))
    print("")
    
    # Store the bank count into the Data Frame
    census_total_pd.set_value(index, "School Count", school_count)
    
    # Reset bank_count (so there is no chance that a previous record is influencing a latter one)
    school_count = 0

# Visualize
census_total_pd.head()
# Out:
# Now retrieving county #0: Maricopa County, Arizona
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=30.6010744,-87.7763333&radius=11000&keyword=international+school&key=AIzaSyDq-O7AaN8YCmdhvXhax8Rh3ljxCH683xE
# Final School Count: 18
#
# Now retrieving county #1: Pima County, Arizona
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=33.7701576,-85.80766&radius=11000&keyword=international+school&key=AIzaSyDq-O7AaN8YCmdhvXhax8Rh3ljxCH683xE
# Final School Count: 14
#
# Now retrieving county #2: Alameda County, California
# https://maps.googleapis.com/maps/api/place/radarsearch/json?location=34.2011537,-86.8220341&radius=11000&keyword=international+school&key=AIzaSyDq-O7AaN8YCmdhvXhax8Rh3ljxCH683xE
# Final School Count: 7
#
# Now retrieving county #3: Contra Costa County, California
# ...

# %%
# Visualize
census_total_pd.head()
# Out:
#    Unnamed: 0  $10,000 to $14,999  $100,000 to $124,999  $125,000 to $149,999  \
# 0           0                 531                  4291                  3147
# 1           1                 178                   572                   297
# 2           2                2833                 14788                 11286
# 3           3                 500                  5407                  3342
# 4           4                1347                  1010                  1228
#
#    $15,000 to $19,999  $150,000 to $199,999  $20,000 to $24,999  \
# 0                1267                  4105                1326
# 1                 112                   508                 236
# 2                2479                 18340                2375
# 3                 648                  6547                 724
# 4                1229                  1029                 904
#
#    $200,000 or more  $25,000 to $29,999  $30,000 to $34,999      ...       \
# ...

# %%
# Save Data to csv
census_total_pd.to_csv("school_competition_pd_3.csv")
