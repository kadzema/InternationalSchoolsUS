# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time

# %%
# Import the census data into a pandas DataFrame
census_asian_2000_pd = pd.read_csv("census_data/Asian/DEC_00_SF3_P151D_with_ann.csv")

# Preview the data
census_asian_2000_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama                43
# 1  0500000US01003  1003  Baldwin County, Alabama               132
# 2  0500000US01005  1005  Barbour County, Alabama                 3
# 3  0500000US01007  1007     Bibb County, Alabama                 6
# 4  0500000US01009  1009   Blount County, Alabama                35
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      NaN                            5
# 1                      NaN                           20
# 2                      NaN                            0
# 3                      NaN                            0
# 4                      NaN                            3
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                 NaN                             0
# 1                                 NaN                             8
# ...

# %%
census_asian_2000_pd["Year"] = "2000"
census_asian_2000_pd["Race"] = "Asian"
census_asian_2000_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama                43
# 1  0500000US01003  1003  Baldwin County, Alabama               132
# 2  0500000US01005  1005  Barbour County, Alabama                 3
# 3  0500000US01007  1007     Bibb County, Alabama                 6
# 4  0500000US01009  1009   Blount County, Alabama                35
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      NaN                            5
# 1                      NaN                           20
# 2                      NaN                            0
# 3                      NaN                            0
# 4                      NaN                            3
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                 NaN                             0
# 1                                 NaN                             8
# ...

# %%
# Preview the data
census_asian_2000_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama                43
# 1  0500000US01003  1003  Baldwin County, Alabama               132
# 2  0500000US01005  1005  Barbour County, Alabama                 3
# 3  0500000US01007  1007     Bibb County, Alabama                 6
# 4  0500000US01009  1009   Blount County, Alabama                35
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      NaN                            5
# 1                      NaN                           20
# 2                      NaN                            0
# 3                      NaN                            0
# 4                      NaN                            3
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                 NaN                             0
# 1                                 NaN                             8
# ...

# %%
# Import the census data into a pandas DataFrame
census_asian_2005_pd = pd.read_csv("census_data/Asian/ACS_05_EST_B19001D_with_ann.csv")

# Preview the data
census_asian_2005_pd.head()
# Out:
#                Id   Id2                       Geography  Estimate; Total:  \
# 0  0500000US01073  1073       Jefferson County, Alabama              2773
# 1  0500000US02020  2020  Anchorage Municipality, Alaska              5933
# 2  0500000US04013  4013        Maricopa County, Arizona             33793
# 3  0500000US04019  4019            Pima County, Arizona              7327
# 4  0500000US06001  6001      Alameda County, California            110554
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      470                           47
# 1                      937                          112
# 2                     2015                         2727
# 3                      707                         1025
# 4                     3320                         9461
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                  82                            37
# ...

# %%
census_asian_2005_pd["Year"] = "2005"
census_asian_2005_pd["Race"] = "Asian"
census_asian_2005_pd.head()
# Out:
#                Id   Id2                       Geography  Estimate; Total:  \
# 0  0500000US01073  1073       Jefferson County, Alabama              2773
# 1  0500000US02020  2020  Anchorage Municipality, Alaska              5933
# 2  0500000US04013  4013        Maricopa County, Arizona             33793
# 3  0500000US04019  4019            Pima County, Arizona              7327
# 4  0500000US06001  6001      Alameda County, California            110554
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      470                           47
# 1                      937                          112
# 2                     2015                         2727
# 3                      707                         1025
# 4                     3320                         9461
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                  82                            37
# ...

# %%
# Import the census data into a pandas DataFrame
census_asian_2008_pd = pd.read_csv("census_data/Asian/ACS_08_1YR_B19001D_with_ann.csv")

# Preview the data
census_asian_2008_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              5943
# 1  0500000US04013  4013         Maricopa County, Arizona             34321
# 2  0500000US04019  4019             Pima County, Arizona              9110
# 3  0500000US06001  6001       Alameda County, California            110737
# 4  0500000US06013  6013  Contra Costa County, California             45055
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      610                          287
# 1                     1884                         1593
# 2                     1112                         1106
# 3                     2770                         5418
# 4                     1729                         1829
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                 258                           323
# ...

# %%
census_asian_2008_pd["Year"] = "2008"
census_asian_2008_pd["Race"] = "Asian"
census_asian_2008_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              5943
# 1  0500000US04013  4013         Maricopa County, Arizona             34321
# 2  0500000US04019  4019             Pima County, Arizona              9110
# 3  0500000US06001  6001       Alameda County, California            110737
# 4  0500000US06013  6013  Contra Costa County, California             45055
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      610                          287
# 1                     1884                         1593
# 2                     1112                         1106
# 3                     2770                         5418
# 4                     1729                         1829
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                 258                           323
# ...

# %%
# Import the census data into a pandas DataFrame
census_asian_2010_pd = pd.read_csv("census_data/Asian/ACS_10_1YR_B19001D_with_ann.csv")

# %%
census_asian_2010_pd["Year"] = "2010"
census_asian_2010_pd["Race"] = "Asian"
census_asian_2010_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              5956
# 1  0500000US04013  4013         Maricopa County, Arizona             38485
# 2  0500000US04019  4019             Pima County, Arizona              9716
# 3  0500000US06001  6001       Alameda County, California            124265
# 4  0500000US06013  6013  Contra Costa County, California             45695
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      924                          252
# 1                     2171                         2975
# 2                     1297                          920
# 3                     3180                         6763
# 4                     1976                         1359
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                 220                           542
# ...

# %%
# Import the census data into a pandas DataFrame
census_asian_2013_pd = pd.read_csv("census_data/Asian/ACS_13_1YR_B19001D_with_ann.csv")

# %%
census_asian_2013_pd["Year"] = "2013"
census_asian_2013_pd["Race"] = "Asian"
census_asian_2013_pd.head()
# Out:
#                Id   Id2                       Geography  Estimate; Total:  \
# 0  0500000US01073  1073       Jefferson County, Alabama              2750
# 1  0500000US02020  2020  Anchorage Municipality, Alaska              6016
# 2  0500000US04013  4013        Maricopa County, Arizona             46554
# 3  0500000US04019  4019            Pima County, Arizona              9867
# 4  0500000US06001  6001      Alameda County, California            136281
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      551                           56
# 1                      885                           70
# 2                     2333                         3790
# 3                     1084                         1632
# 4                     3185                         8239
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                  99                           279
# ...

# %%
# Import the census data into a pandas DataFrame
census_asian_2016_pd = pd.read_csv("census_data/Asian/ACS_16_1YR_B19001D_with_ann.csv")
census_asian_2016_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              7189
# 1  0500000US04013  4013         Maricopa County, Arizona             55747
# 2  0500000US04019  4019             Pima County, Arizona             11076
# 3  0500000US06001  6001       Alameda County, California            152847
# 4  0500000US06013  6013  Contra Costa County, California             55060
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      980                            0
# 1                     2351                         4313
# 2                     1165                         1520
# 3                     3133                         7527
# 4                     2124                         1906
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                 155                           411
# ...

# %%
census_asian_2016_pd["Year"] = "2016"
census_asian_2016_pd["Race"] = "Asian"
census_asian_2016_pd.head()
# Out:
#                Id   Id2                        Geography  Estimate; Total:  \
# 0  0500000US02020  2020   Anchorage Municipality, Alaska              7189
# 1  0500000US04013  4013         Maricopa County, Arizona             55747
# 2  0500000US04019  4019             Pima County, Arizona             11076
# 3  0500000US06001  6001       Alameda County, California            152847
# 4  0500000US06013  6013  Contra Costa County, California             55060
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      980                            0
# 1                     2351                         4313
# 2                     1165                         1520
# 3                     3133                         7527
# 4                     2124                         1906
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                 155                           411
# ...

# %%
# Concatenate dataframes
census_asian_total_pd = pd.concat([census_asian_2000_pd, census_asian_2005_pd, census_asian_2008_pd, census_asian_2010_pd, census_asian_2013_pd, census_asian_2016_pd], ignore_index=True)
census_asian_total_pd.head()
# Out:
#                Id   Id2                Geography  Estimate; Total:  \
# 0  0500000US01001  1001  Autauga County, Alabama                43
# 1  0500000US01003  1003  Baldwin County, Alabama               132
# 2  0500000US01005  1005  Barbour County, Alabama                 3
# 3  0500000US01007  1007     Bibb County, Alabama                 6
# 4  0500000US01009  1009   Blount County, Alabama                35
#
#    Margin of Error; Total:  Estimate; Less than $10,000  \
# 0                      NaN                            5
# 1                      NaN                           20
# 2                      NaN                            0
# 3                      NaN                            0
# 4                      NaN                            3
#
#    Margin of Error; Less than $10,000  Estimate; $10,000 to $14,999  \
# 0                                 NaN                             0
# 1                                 NaN                             8
# ...

# %%
# Save Data to csv
census_asian_total_pd.to_csv("census_data/census_asian_total_pd.csv")
